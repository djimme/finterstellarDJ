# %% [markdown]
# <a href="https://colab.research.google.com/github/djimme/finterstellarDJ/blob/master/Quant_2412.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import finterstellar as fs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5dae837ff9ef> in <cell line: 1>()
# ----> 1 import finterstellar as fs
#
# ModuleNotFoundError: No module named 'finterstellar'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df_AAPL = fs.get_price('AAPL', start_date="2024-01-01", end_date="2024-12-05")
df_AAPL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-01654d908534> in <cell line: 1>()
# ----> 1 df_AAPL = fs.get_price('AAPL', start_date="2024-01-01", end_date="2024-12-05")
#       2 df_AAPL
#
# NameError: name 'fs' is not defined

# %%
fs.draw_chart(df_AAPL, right='AAPL')

# %%
fs.rsi(df_AAPL)

# %%
fs.draw_chart(df_AAPL, left='rsi', right='AAPL')
